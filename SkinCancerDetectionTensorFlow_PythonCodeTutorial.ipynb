# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tensorflow.keras.utils import get_file
from sklearn.metrics import roc_curve, auc, confusion_matrix
from imblearn.metrics import sensitivity_score, specificity_score

import os
import glob
import zipfile
import random

# to get consistent results after multiple runs
tf.random.set_seed(7)
np.random.seed(7)
random.seed(7)

# 0 for benign, 1 for malignant
class_names = ["benign", "malignant"]


def download_and_extract_dataset():
  # dataset from https://github.com/udacity/dermatologist-ai
  # 5.3GB
  train_url = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip"
  # 824.5MB
  valid_url = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip"
  # 5.1GB
  test_url  = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip"
  for i, download_link in enumerate([valid_url, train_url, test_url]):
    temp_file = f"temp{i}.zip"
    data_dir = get_file(origin=download_link, fname=os.path.join(os.getcwd(), temp_file))
    print("Extracting", download_link)
    with zipfile.ZipFile(data_dir, "r") as z:
      z.extractall("data")
    # remove the temp file
    os.remove(temp_file)

# comment the below line if you already downloaded the dataset
download_and_extract_dataset()
# Out:
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip
# 864538487/864538487 [==============================] - 18s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip
# 5736557430/5736557430 [==============================] - 73s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip
# 5528640507/5528640507 [==============================] - 71s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip

# %%
# preparing data
# generate CSV metadata file to read img paths and labels from it
def generate_csv(folder, label2int):
    folder_name = os.path.basename(folder)
    labels = list(label2int)
    # generate CSV file
    df = pd.DataFrame(columns=["filepath", "label"])
    i = 0
    for label in labels:
        print("Reading", os.path.join(folder, label, "*"))
        for filepath in glob.glob(os.path.join(folder, label, "*")):
            df.loc[i] = [filepath, label2int[label]]
            i += 1
    output_file = f"{folder_name}.csv"
    print("Saving", output_file)
    df.to_csv(output_file)

# generate CSV files for all data portions, labeling nevus and seborrheic keratosis
# as 0 (benign), and melanoma as 1 (malignant)
# you should replace "data" path to your extracted dataset path
# don't replace if you used download_and_extract_dataset() function
generate_csv("data/train", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
generate_csv("data/valid", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
generate_csv("data/test", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
# Out:
# Reading data/train/nevus/*
# Reading data/train/seborrheic_keratosis/*
# Reading data/train/melanoma/*
# Saving train.csv
# Reading data/valid/nevus/*
# Reading data/valid/seborrheic_keratosis/*
# Reading data/valid/melanoma/*
# Saving valid.csv
# Reading data/test/nevus/*
# Reading data/test/seborrheic_keratosis/*
# Reading data/test/melanoma/*
# Saving test.csv

# %%
# loading data
train_metadata_filename = "train.csv"
valid_metadata_filename = "valid.csv"
# load CSV files as DataFrames
df_train = pd.read_csv(train_metadata_filename)
df_valid = pd.read_csv(valid_metadata_filename)
n_training_samples = len(df_train)
n_validation_samples = len(df_valid)
print("Number of training samples:", n_training_samples)
print("Number of validation samples:", n_validation_samples)
train_ds = tf.data.Dataset.from_tensor_slices((df_train["filepath"], df_train["label"]))
valid_ds = tf.data.Dataset.from_tensor_slices((df_valid["filepath"], df_valid["label"]))
# Out:
# Number of training samples: 2000
# Number of validation samples: 150

# %%
# preprocess data
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize the image to the desired size.
  return tf.image.resize(img, [299, 299])


def process_path(filepath, label):
  # load the raw data from the file as a string
  img = tf.io.read_file(filepath)
  img = decode_img(img)
  return img, label


valid_ds = valid_ds.map(process_path)
train_ds = train_ds.map(process_path)
# test_ds = test_ds
for image, label in train_ds.take(1):
    print("Image shape:", image.shape)
    print("Label:", label.numpy())
# Out:
# Image shape: (299, 299, 3)
# Label: 0

# %%
# training parameters
batch_size = 64
optimizer = "rmsprop"

# %%
def prepare_for_training(ds, cache=True, batch_size=64, shuffle_buffer_size=1000):
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()
  # shuffle the dataset
  ds = ds.shuffle(buffer_size=shuffle_buffer_size)

  # Repeat forever
  ds = ds.repeat()
  # split to batches
  ds = ds.batch(batch_size)

  # `prefetch` lets the dataset fetch batches in the background while the model
  # is training.
  ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

  return ds


valid_ds = prepare_for_training(valid_ds, batch_size=batch_size, cache="valid-cached-data")
train_ds = prepare_for_training(train_ds, batch_size=batch_size, cache="train-cached-data")

# %%
batch = next(iter(valid_ds))

def show_batch(batch):
  plt.figure(figsize=(12,12))
  for n in range(25):
      ax = plt.subplot(5,5,n+1)
      plt.imshow(batch[0][n])
      plt.title(class_names[batch[1][n].numpy()].title())
      plt.axis('off')

show_batch(batch)

# %%
# building the model
# InceptionV3 model & pre-trained weights
module_url = "https://tfhub.dev/google/tf2-preview/inception_v3/feature_vector/4"
m = tf.keras.Sequential([
    hub.KerasLayer(module_url, output_shape=[2048], trainable=False),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

m.build([None, 299, 299, 3])
m.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=["accuracy"])
m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 2048)              21802784
#
#  dense (Dense)               (None, 1)                 2049
#
# =================================================================
# Total params: 21804833 (83.18 MB)
# Trainable params: 2049 (8.00 KB)
# Non-trainable params: 21802784 (83.17 MB)
# _________________________________________________________________

# %%
model_name = f"benign-vs-malignant_{batch_size}_{optimizer}"
tensorboard = tf.keras.callbacks.TensorBoard(log_dir=os.path.join("logs", model_name))
# saves model checkpoint whenever we reach better weights
modelcheckpoint = tf.keras.callbacks.ModelCheckpoint(model_name + "_{val_loss:.3f}.h5", save_best_only=True, verbose=1)

history = m.fit(train_ds, validation_data=valid_ds,
                steps_per_epoch=n_training_samples // batch_size,
                validation_steps=n_validation_samples // batch_size, verbose=1, epochs=100,
                callbacks=[tensorboard, modelcheckpoint])
# Out:
# Epoch 1/100
# 31/31 [==============================] - ETA: 0s - loss: 0.4090 - accuracy: 0.8014
# Epoch 1: val_loss improved from inf to 0.50873, saving model to benign-vs-malignant_64_rmsprop_0.509.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 31/31 [==============================] - 230s 4s/step - loss: 0.4090 - accuracy: 0.8014 - val_loss: 0.5087 - val_accuracy: 0.8047
# Epoch 2/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3909 - accuracy: 0.8201
# Epoch 2: val_loss improved from 0.50873 to 0.47483, saving model to benign-vs-malignant_64_rmsprop_0.475.h5
# 31/31 [==============================] - 13s 436ms/step - loss: 0.3909 - accuracy: 0.8201 - val_loss: 0.4748 - val_accuracy: 0.7969
# Epoch 3/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3758 - accuracy: 0.8286
# Epoch 3: val_loss improved from 0.47483 to 0.43331, saving model to benign-vs-malignant_64_rmsprop_0.433.h5
# 31/31 [==============================] - 12s 393ms/step - loss: 0.3758 - accuracy: 0.8286 - val_loss: 0.4333 - val_accuracy: 0.8125
# Epoch 4/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3552 - accuracy: 0.8362
# Epoch 4: val_loss did not improve from 0.43331
# 31/31 [==============================] - 9s 299ms/step - loss: 0.3552 - accuracy: 0.8362 - val_loss: 0.4730 - val_accuracy: 0.7812
# Epoch 5/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3569 - accuracy: 0.8407
# Epoch 5: val_loss did not improve from 0.43331
# 31/31 [==============================] - 9s 309ms/step - loss: 0.3569 - accuracy: 0.8407 - val_loss: 0.4606 - val_accuracy: 0.7734
# Epoch 6/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3422 - accuracy: 0.8432
# Epoch 6: val_loss did not improve from 0.43331
# 31/31 [==============================] - 9s 292ms/step - loss: 0.3422 - accuracy: 0.8432 - val_loss: 0.4450 - val_accuracy: 0.8047
# Epoch 7/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3437 - accuracy: 0.8473
# Epoch 7: val_loss did not improve from 0.43331
# 31/31 [==============================] - 9s 281ms/step - loss: 0.3437 - accuracy: 0.8473 - val_loss: 0.4619 - val_accuracy: 0.7891
# Epoch 8/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3361 - accuracy: 0.8488
# Epoch 8: val_loss did not improve from 0.43331
# 31/31 [==============================] - 9s 285ms/step - loss: 0.3361 - accuracy: 0.8488 - val_loss: 0.4882 - val_accuracy: 0.7656
# Epoch 9/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3397 - accuracy: 0.8397
# Epoch 9: val_loss improved from 0.43331 to 0.42731, saving model to benign-vs-malignant_64_rmsprop_0.427.h5
# 31/31 [==============================] - 9s 302ms/step - loss: 0.3397 - accuracy: 0.8397 - val_loss: 0.4273 - val_accuracy: 0.8281
# Epoch 10/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3182 - accuracy: 0.8553
# Epoch 10: val_loss did not improve from 0.42731
# 31/31 [==============================] - 8s 273ms/step - loss: 0.3182 - accuracy: 0.8553 - val_loss: 0.5269 - val_accuracy: 0.6875
# Epoch 11/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3212 - accuracy: 0.8564
# Epoch 11: val_loss did not improve from 0.42731
# 31/31 [==============================] - 9s 277ms/step - loss: 0.3212 - accuracy: 0.8564 - val_loss: 0.4687 - val_accuracy: 0.7891
# Epoch 12/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3188 - accuracy: 0.8569
# Epoch 12: val_loss did not improve from 0.42731
# 31/31 [==============================] - 9s 287ms/step - loss: 0.3188 - accuracy: 0.8569 - val_loss: 0.4522 - val_accuracy: 0.8203
# Epoch 13/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3352 - accuracy: 0.8508
# Epoch 13: val_loss did not improve from 0.42731
# 31/31 [==============================] - 9s 291ms/step - loss: 0.3352 - accuracy: 0.8508 - val_loss: 0.4364 - val_accuracy: 0.8047
# Epoch 14/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2967 - accuracy: 0.8760
# Epoch 14: val_loss did not improve from 0.42731
# 31/31 [==============================] - 8s 272ms/step - loss: 0.2967 - accuracy: 0.8760 - val_loss: 0.5497 - val_accuracy: 0.6562
# Epoch 15/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3254 - accuracy: 0.8523
# Epoch 15: val_loss did not improve from 0.42731
# 31/31 [==============================] - 9s 277ms/step - loss: 0.3254 - accuracy: 0.8523 - val_loss: 0.4464 - val_accuracy: 0.7812
# Epoch 16/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3111 - accuracy: 0.8624
# Epoch 16: val_loss did not improve from 0.42731
# 31/31 [==============================] - 9s 291ms/step - loss: 0.3111 - accuracy: 0.8624 - val_loss: 0.4499 - val_accuracy: 0.8047
# Epoch 17/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3252 - accuracy: 0.8609
# Epoch 17: val_loss did not improve from 0.42731
# 31/31 [==============================] - 9s 292ms/step - loss: 0.3252 - accuracy: 0.8609 - val_loss: 0.4566 - val_accuracy: 0.8125
# Epoch 18/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3147 - accuracy: 0.8690
# Epoch 18: val_loss did not improve from 0.42731
# 31/31 [==============================] - 8s 271ms/step - loss: 0.3147 - accuracy: 0.8690 - val_loss: 0.4411 - val_accuracy: 0.7969
# Epoch 19/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2994 - accuracy: 0.8765
# Epoch 19: val_loss did not improve from 0.42731
# 31/31 [==============================] - 9s 288ms/step - loss: 0.2994 - accuracy: 0.8765 - val_loss: 0.4316 - val_accuracy: 0.8125
# Epoch 20/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3015 - accuracy: 0.8695
# Epoch 20: val_loss did not improve from 0.42731
# 31/31 [==============================] - 8s 275ms/step - loss: 0.3015 - accuracy: 0.8695 - val_loss: 0.4379 - val_accuracy: 0.8047
# Epoch 21/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3026 - accuracy: 0.8664
# Epoch 21: val_loss did not improve from 0.42731
# 31/31 [==============================] - 9s 281ms/step - loss: 0.3026 - accuracy: 0.8664 - val_loss: 0.4398 - val_accuracy: 0.7969
# Epoch 22/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3058 - accuracy: 0.8735
# Epoch 22: val_loss did not improve from 0.42731
# 31/31 [==============================] - 9s 285ms/step - loss: 0.3058 - accuracy: 0.8735 - val_loss: 0.4446 - val_accuracy: 0.8047
# Epoch 23/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3027 - accuracy: 0.8664
# Epoch 23: val_loss did not improve from 0.42731
# 31/31 [==============================] - 9s 278ms/step - loss: 0.3027 - accuracy: 0.8664 - val_loss: 0.4635 - val_accuracy: 0.8047
# Epoch 24/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2910 - accuracy: 0.8710
# Epoch 24: val_loss did not improve from 0.42731
# 31/31 [==============================] - 8s 273ms/step - loss: 0.2910 - accuracy: 0.8710 - val_loss: 0.4542 - val_accuracy: 0.7969
# Epoch 25/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2971 - accuracy: 0.8790
# Epoch 25: val_loss did not improve from 0.42731
# 31/31 [==============================] - 9s 287ms/step - loss: 0.2971 - accuracy: 0.8790 - val_loss: 0.4332 - val_accuracy: 0.7891
# Epoch 26/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3017 - accuracy: 0.8644
# Epoch 26: val_loss improved from 0.42731 to 0.42716, saving model to benign-vs-malignant_64_rmsprop_0.427.h5
# 31/31 [==============================] - 9s 286ms/step - loss: 0.3017 - accuracy: 0.8644 - val_loss: 0.4272 - val_accuracy: 0.8203
# Epoch 27/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2859 - accuracy: 0.8805
# Epoch 27: val_loss did not improve from 0.42716
# 31/31 [==============================] - 9s 277ms/step - loss: 0.2859 - accuracy: 0.8805 - val_loss: 0.4673 - val_accuracy: 0.7734
# Epoch 28/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2826 - accuracy: 0.8816
# Epoch 28: val_loss did not improve from 0.42716
# 31/31 [==============================] - 9s 291ms/step - loss: 0.2826 - accuracy: 0.8816 - val_loss: 0.4454 - val_accuracy: 0.8047
# Epoch 29/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.8634
# Epoch 29: val_loss did not improve from 0.42716
# 31/31 [==============================] - 8s 270ms/step - loss: 0.3069 - accuracy: 0.8634 - val_loss: 0.4537 - val_accuracy: 0.8203
# Epoch 30/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2760 - accuracy: 0.8871
# Epoch 30: val_loss did not improve from 0.42716
# 31/31 [==============================] - 8s 273ms/step - loss: 0.2760 - accuracy: 0.8871 - val_loss: 0.4692 - val_accuracy: 0.7891
# Epoch 31/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2865 - accuracy: 0.8760
# Epoch 31: val_loss did not improve from 0.42716
# 31/31 [==============================] - 9s 289ms/step - loss: 0.2865 - accuracy: 0.8760 - val_loss: 0.4738 - val_accuracy: 0.8203
# Epoch 32/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2688 - accuracy: 0.8881
# Epoch 32: val_loss improved from 0.42716 to 0.40873, saving model to benign-vs-malignant_64_rmsprop_0.409.h5
# 31/31 [==============================] - 9s 284ms/step - loss: 0.2688 - accuracy: 0.8881 - val_loss: 0.4087 - val_accuracy: 0.8203
# Epoch 33/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2776 - accuracy: 0.8780
# Epoch 33: val_loss did not improve from 0.40873
# 31/31 [==============================] - 9s 276ms/step - loss: 0.2776 - accuracy: 0.8780 - val_loss: 0.4198 - val_accuracy: 0.8203
# Epoch 34/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2781 - accuracy: 0.8866
# Epoch 34: val_loss did not improve from 0.40873
# 31/31 [==============================] - 8s 274ms/step - loss: 0.2781 - accuracy: 0.8866 - val_loss: 0.4499 - val_accuracy: 0.7891
# Epoch 35/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2788 - accuracy: 0.8816
# Epoch 35: val_loss did not improve from 0.40873
# 31/31 [==============================] - 9s 279ms/step - loss: 0.2788 - accuracy: 0.8816 - val_loss: 0.4251 - val_accuracy: 0.8281
# Epoch 36/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2626 - accuracy: 0.8906
# Epoch 36: val_loss did not improve from 0.40873
# 31/31 [==============================] - 8s 271ms/step - loss: 0.2626 - accuracy: 0.8906 - val_loss: 0.4352 - val_accuracy: 0.7969
# Epoch 37/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2898 - accuracy: 0.8690
# Epoch 37: val_loss did not improve from 0.40873
# 31/31 [==============================] - 9s 292ms/step - loss: 0.2898 - accuracy: 0.8690 - val_loss: 0.4379 - val_accuracy: 0.8203
# Epoch 38/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2677 - accuracy: 0.8856
# Epoch 38: val_loss did not improve from 0.40873
# 31/31 [==============================] - 9s 290ms/step - loss: 0.2677 - accuracy: 0.8856 - val_loss: 0.4847 - val_accuracy: 0.7500
# Epoch 39/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2769 - accuracy: 0.8886
# Epoch 39: val_loss did not improve from 0.40873
# 31/31 [==============================] - 9s 286ms/step - loss: 0.2769 - accuracy: 0.8886 - val_loss: 0.4604 - val_accuracy: 0.7969
# Epoch 40/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2672 - accuracy: 0.8921
# Epoch 40: val_loss did not improve from 0.40873
# 31/31 [==============================] - 9s 290ms/step - loss: 0.2672 - accuracy: 0.8921 - val_loss: 0.4153 - val_accuracy: 0.8359
# Epoch 41/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2735 - accuracy: 0.8800
# Epoch 41: val_loss did not improve from 0.40873
# 31/31 [==============================] - 9s 290ms/step - loss: 0.2735 - accuracy: 0.8800 - val_loss: 0.4713 - val_accuracy: 0.7891
# Epoch 42/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2739 - accuracy: 0.8775
# Epoch 42: val_loss did not improve from 0.40873
# 31/31 [==============================] - 8s 271ms/step - loss: 0.2739 - accuracy: 0.8775 - val_loss: 0.4254 - val_accuracy: 0.8125
# Epoch 43/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2662 - accuracy: 0.8891
# Epoch 43: val_loss did not improve from 0.40873
# 31/31 [==============================] - 9s 290ms/step - loss: 0.2662 - accuracy: 0.8891 - val_loss: 0.4776 - val_accuracy: 0.7969
# Epoch 44/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2683 - accuracy: 0.8926
# Epoch 44: val_loss did not improve from 0.40873
# 31/31 [==============================] - 8s 275ms/step - loss: 0.2683 - accuracy: 0.8926 - val_loss: 0.4626 - val_accuracy: 0.7969
# Epoch 45/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2687 - accuracy: 0.8821
# Epoch 45: val_loss did not improve from 0.40873
# 31/31 [==============================] - 9s 277ms/step - loss: 0.2687 - accuracy: 0.8821 - val_loss: 0.4513 - val_accuracy: 0.8125
# Epoch 46/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2699 - accuracy: 0.8957
# Epoch 46: val_loss did not improve from 0.40873
# 31/31 [==============================] - 9s 288ms/step - loss: 0.2699 - accuracy: 0.8957 - val_loss: 0.4494 - val_accuracy: 0.8047
# Epoch 47/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2650 - accuracy: 0.8881
# Epoch 47: val_loss did not improve from 0.40873
# 31/31 [==============================] - 9s 281ms/step - loss: 0.2650 - accuracy: 0.8881 - val_loss: 0.4559 - val_accuracy: 0.8047
# Epoch 48/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2637 - accuracy: 0.8846
# Epoch 48: val_loss did not improve from 0.40873
# 31/31 [==============================] - 9s 276ms/step - loss: 0.2637 - accuracy: 0.8846 - val_loss: 0.4379 - val_accuracy: 0.8203
# Epoch 49/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2649 - accuracy: 0.8921
# Epoch 49: val_loss did not improve from 0.40873
# 31/31 [==============================] - 8s 270ms/step - loss: 0.2649 - accuracy: 0.8921 - val_loss: 0.4526 - val_accuracy: 0.8047
# Epoch 50/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2578 - accuracy: 0.8901
# Epoch 50: val_loss did not improve from 0.40873
# 31/31 [==============================] - 9s 290ms/step - loss: 0.2578 - accuracy: 0.8901 - val_loss: 0.4594 - val_accuracy: 0.7891
# Epoch 51/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2598 - accuracy: 0.8947
# Epoch 51: val_loss improved from 0.40873 to 0.38975, saving model to benign-vs-malignant_64_rmsprop_0.390.h5
# 31/31 [==============================] - 9s 295ms/step - loss: 0.2598 - accuracy: 0.8947 - val_loss: 0.3897 - val_accuracy: 0.8438
# Epoch 52/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2621 - accuracy: 0.8926
# Epoch 52: val_loss did not improve from 0.38975
# 31/31 [==============================] - 10s 317ms/step - loss: 0.2621 - accuracy: 0.8926 - val_loss: 0.4280 - val_accuracy: 0.7969
# Epoch 53/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2581 - accuracy: 0.8972
# Epoch 53: val_loss did not improve from 0.38975
# 31/31 [==============================] - 8s 268ms/step - loss: 0.2581 - accuracy: 0.8972 - val_loss: 0.4445 - val_accuracy: 0.8047
# Epoch 54/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2672 - accuracy: 0.8921
# Epoch 54: val_loss did not improve from 0.38975
# 31/31 [==============================] - 9s 284ms/step - loss: 0.2672 - accuracy: 0.8921 - val_loss: 0.4697 - val_accuracy: 0.7656
# Epoch 55/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2414 - accuracy: 0.9022
# Epoch 55: val_loss did not improve from 0.38975
# 31/31 [==============================] - 9s 280ms/step - loss: 0.2414 - accuracy: 0.9022 - val_loss: 0.4399 - val_accuracy: 0.8125
# Epoch 56/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2524 - accuracy: 0.8936
# Epoch 56: val_loss did not improve from 0.38975
# 31/31 [==============================] - 9s 288ms/step - loss: 0.2524 - accuracy: 0.8936 - val_loss: 0.4017 - val_accuracy: 0.8281
# Epoch 57/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2553 - accuracy: 0.8942
# Epoch 57: val_loss did not improve from 0.38975
# 31/31 [==============================] - 8s 271ms/step - loss: 0.2553 - accuracy: 0.8942 - val_loss: 0.4441 - val_accuracy: 0.8047
# Epoch 58/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2533 - accuracy: 0.8947
# Epoch 58: val_loss did not improve from 0.38975
# 31/31 [==============================] - 9s 293ms/step - loss: 0.2533 - accuracy: 0.8947 - val_loss: 0.4208 - val_accuracy: 0.8203
# Epoch 59/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2574 - accuracy: 0.8972
# Epoch 59: val_loss did not improve from 0.38975
# 31/31 [==============================] - 9s 294ms/step - loss: 0.2574 - accuracy: 0.8972 - val_loss: 0.4857 - val_accuracy: 0.7891
# Epoch 60/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2542 - accuracy: 0.8972
# Epoch 60: val_loss did not improve from 0.38975
# 31/31 [==============================] - 11s 374ms/step - loss: 0.2542 - accuracy: 0.8972 - val_loss: 0.4729 - val_accuracy: 0.7734
# Epoch 61/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2494 - accuracy: 0.9068
# Epoch 61: val_loss did not improve from 0.38975
# 31/31 [==============================] - 14s 457ms/step - loss: 0.2494 - accuracy: 0.9068 - val_loss: 0.4765 - val_accuracy: 0.7500
# Epoch 62/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2532 - accuracy: 0.8936
# Epoch 62: val_loss did not improve from 0.38975
# 31/31 [==============================] - 9s 305ms/step - loss: 0.2532 - accuracy: 0.8936 - val_loss: 0.4437 - val_accuracy: 0.8125
# Epoch 63/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2536 - accuracy: 0.8942
# Epoch 63: val_loss did not improve from 0.38975
# 31/31 [==============================] - 13s 415ms/step - loss: 0.2536 - accuracy: 0.8942 - val_loss: 0.4430 - val_accuracy: 0.8047
# Epoch 64/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2511 - accuracy: 0.8982
# Epoch 64: val_loss did not improve from 0.38975
# 31/31 [==============================] - 13s 440ms/step - loss: 0.2511 - accuracy: 0.8982 - val_loss: 0.4591 - val_accuracy: 0.8281
# Epoch 65/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2641 - accuracy: 0.8936
# Epoch 65: val_loss did not improve from 0.38975
# 31/31 [==============================] - 19s 615ms/step - loss: 0.2641 - accuracy: 0.8936 - val_loss: 0.4306 - val_accuracy: 0.8281
# Epoch 66/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2248 - accuracy: 0.9068
# Epoch 66: val_loss did not improve from 0.38975
# 31/31 [==============================] - 10s 330ms/step - loss: 0.2248 - accuracy: 0.9068 - val_loss: 0.4461 - val_accuracy: 0.8203
# Epoch 67/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2414 - accuracy: 0.8987
# Epoch 67: val_loss did not improve from 0.38975
# 31/31 [==============================] - 10s 324ms/step - loss: 0.2414 - accuracy: 0.8987 - val_loss: 0.4432 - val_accuracy: 0.8125
# Epoch 68/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2449 - accuracy: 0.9007
# Epoch 68: val_loss did not improve from 0.38975
# 31/31 [==============================] - 13s 431ms/step - loss: 0.2449 - accuracy: 0.9007 - val_loss: 0.4602 - val_accuracy: 0.8125
# Epoch 69/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2410 - accuracy: 0.9047
# Epoch 69: val_loss did not improve from 0.38975
# 31/31 [==============================] - 11s 371ms/step - loss: 0.2410 - accuracy: 0.9047 - val_loss: 0.4434 - val_accuracy: 0.8125
# Epoch 70/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2542 - accuracy: 0.8962
# Epoch 70: val_loss did not improve from 0.38975
# 31/31 [==============================] - 10s 331ms/step - loss: 0.2542 - accuracy: 0.8962 - val_loss: 0.4495 - val_accuracy: 0.8359
# Epoch 71/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2289 - accuracy: 0.9138
# Epoch 71: val_loss did not improve from 0.38975
# 31/31 [==============================] - 10s 332ms/step - loss: 0.2289 - accuracy: 0.9138 - val_loss: 0.3982 - val_accuracy: 0.8281
# Epoch 72/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2427 - accuracy: 0.9017
# Epoch 72: val_loss did not improve from 0.38975
# 31/31 [==============================] - 13s 413ms/step - loss: 0.2427 - accuracy: 0.9017 - val_loss: 0.4764 - val_accuracy: 0.8203
# Epoch 73/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2302 - accuracy: 0.9047
# Epoch 73: val_loss did not improve from 0.38975
# 31/31 [==============================] - 10s 324ms/step - loss: 0.2302 - accuracy: 0.9047 - val_loss: 0.6942 - val_accuracy: 0.7969
# Epoch 74/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2394 - accuracy: 0.9032
# Epoch 74: val_loss did not improve from 0.38975
# 31/31 [==============================] - 26s 850ms/step - loss: 0.2394 - accuracy: 0.9032 - val_loss: 0.4914 - val_accuracy: 0.8516
# Epoch 75/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2276 - accuracy: 0.9158
# Epoch 75: val_loss did not improve from 0.38975
# 31/31 [==============================] - 13s 415ms/step - loss: 0.2276 - accuracy: 0.9158 - val_loss: 0.5545 - val_accuracy: 0.8203
# Epoch 76/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2412 - accuracy: 0.9007
# Epoch 76: val_loss did not improve from 0.38975
# 31/31 [==============================] - 13s 418ms/step - loss: 0.2412 - accuracy: 0.9007 - val_loss: 0.7299 - val_accuracy: 0.7891
# Epoch 77/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2409 - accuracy: 0.8967
# Epoch 77: val_loss did not improve from 0.38975
# 31/31 [==============================] - 13s 414ms/step - loss: 0.2409 - accuracy: 0.8967 - val_loss: 0.6724 - val_accuracy: 0.8203
# Epoch 78/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2489 - accuracy: 0.8962
# Epoch 78: val_loss did not improve from 0.38975
# 31/31 [==============================] - 13s 421ms/step - loss: 0.2489 - accuracy: 0.8962 - val_loss: 0.6306 - val_accuracy: 0.8203
# Epoch 79/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2299 - accuracy: 0.9088
# Epoch 79: val_loss did not improve from 0.38975
# 31/31 [==============================] - 13s 432ms/step - loss: 0.2299 - accuracy: 0.9088 - val_loss: 0.8112 - val_accuracy: 0.7812
# Epoch 80/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2311 - accuracy: 0.9073
# Epoch 80: val_loss did not improve from 0.38975
# 31/31 [==============================] - 14s 436ms/step - loss: 0.2311 - accuracy: 0.9073 - val_loss: 0.8103 - val_accuracy: 0.7891
# Epoch 81/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2407 - accuracy: 0.8987
# Epoch 81: val_loss did not improve from 0.38975
# 31/31 [==============================] - 13s 421ms/step - loss: 0.2407 - accuracy: 0.8987 - val_loss: 0.8095 - val_accuracy: 0.7969
# Epoch 82/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2331 - accuracy: 0.9017
# Epoch 82: val_loss did not improve from 0.38975
# 31/31 [==============================] - 14s 463ms/step - loss: 0.2331 - accuracy: 0.9017 - val_loss: 0.8701 - val_accuracy: 0.7969
# Epoch 83/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2295 - accuracy: 0.9098
# Epoch 83: val_loss did not improve from 0.38975
# 31/31 [==============================] - 11s 373ms/step - loss: 0.2295 - accuracy: 0.9098 - val_loss: 0.9022 - val_accuracy: 0.8047
# Epoch 84/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2484 - accuracy: 0.8992
# Epoch 84: val_loss did not improve from 0.38975
# 31/31 [==============================] - 19s 637ms/step - loss: 0.2484 - accuracy: 0.8992 - val_loss: 0.8976 - val_accuracy: 0.7969
# Epoch 85/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2354 - accuracy: 0.9068
# Epoch 85: val_loss did not improve from 0.38975
# 31/31 [==============================] - 23s 732ms/step - loss: 0.2354 - accuracy: 0.9068 - val_loss: 0.7552 - val_accuracy: 0.8125
# Epoch 86/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2261 - accuracy: 0.9128
# Epoch 86: val_loss did not improve from 0.38975
# 31/31 [==============================] - 15s 500ms/step - loss: 0.2261 - accuracy: 0.9128 - val_loss: 1.0076 - val_accuracy: 0.7891
# Epoch 87/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2349 - accuracy: 0.9073
# Epoch 87: val_loss did not improve from 0.38975
# 31/31 [==============================] - 15s 501ms/step - loss: 0.2349 - accuracy: 0.9073 - val_loss: 0.8804 - val_accuracy: 0.8047
# Epoch 88/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2231 - accuracy: 0.9143
# Epoch 88: val_loss did not improve from 0.38975
# 31/31 [==============================] - 14s 469ms/step - loss: 0.2231 - accuracy: 0.9143 - val_loss: 0.9991 - val_accuracy: 0.7812
# Epoch 89/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2284 - accuracy: 0.9108
# Epoch 89: val_loss did not improve from 0.38975
# 31/31 [==============================] - 18s 589ms/step - loss: 0.2284 - accuracy: 0.9108 - val_loss: 0.8805 - val_accuracy: 0.8125
# Epoch 90/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2353 - accuracy: 0.9093
# Epoch 90: val_loss did not improve from 0.38975
# 31/31 [==============================] - 16s 518ms/step - loss: 0.2353 - accuracy: 0.9093 - val_loss: 0.7895 - val_accuracy: 0.8125
# Epoch 91/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2307 - accuracy: 0.9128
# Epoch 91: val_loss did not improve from 0.38975
# 31/31 [==============================] - 15s 499ms/step - loss: 0.2307 - accuracy: 0.9128 - val_loss: 0.7493 - val_accuracy: 0.8125
# Epoch 92/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2346 - accuracy: 0.9022
# Epoch 92: val_loss did not improve from 0.38975
# 31/31 [==============================] - 15s 488ms/step - loss: 0.2346 - accuracy: 0.9022 - val_loss: 0.9077 - val_accuracy: 0.7969
# Epoch 93/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2304 - accuracy: 0.9158
# Epoch 93: val_loss did not improve from 0.38975
# 31/31 [==============================] - 15s 487ms/step - loss: 0.2304 - accuracy: 0.9158 - val_loss: 0.8027 - val_accuracy: 0.7969
# Epoch 94/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2279 - accuracy: 0.9108
# Epoch 94: val_loss did not improve from 0.38975
# 31/31 [==============================] - 15s 477ms/step - loss: 0.2279 - accuracy: 0.9108 - val_loss: 0.8070 - val_accuracy: 0.8047
# Epoch 95/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2228 - accuracy: 0.9173
# Epoch 95: val_loss did not improve from 0.38975
# 31/31 [==============================] - 15s 479ms/step - loss: 0.2228 - accuracy: 0.9173 - val_loss: 0.7356 - val_accuracy: 0.8203
# Epoch 96/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2183 - accuracy: 0.9178
# Epoch 96: val_loss did not improve from 0.38975
# 31/31 [==============================] - 15s 473ms/step - loss: 0.2183 - accuracy: 0.9178 - val_loss: 0.8670 - val_accuracy: 0.8047
# Epoch 97/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2293 - accuracy: 0.9032
# Epoch 97: val_loss did not improve from 0.38975
# 31/31 [==============================] - 15s 492ms/step - loss: 0.2293 - accuracy: 0.9032 - val_loss: 0.7430 - val_accuracy: 0.8125
# Epoch 98/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2159 - accuracy: 0.9209
# Epoch 98: val_loss did not improve from 0.38975
# 31/31 [==============================] - 15s 490ms/step - loss: 0.2159 - accuracy: 0.9209 - val_loss: 0.9870 - val_accuracy: 0.7734
# Epoch 99/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2205 - accuracy: 0.9204
# Epoch 99: val_loss did not improve from 0.38975
# 31/31 [==============================] - 15s 485ms/step - loss: 0.2205 - accuracy: 0.9204 - val_loss: 0.9230 - val_accuracy: 0.7891
# Epoch 100/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2287 - accuracy: 0.9108
# Epoch 100: val_loss did not improve from 0.38975
# 31/31 [==============================] - 15s 480ms/step - loss: 0.2287 - accuracy: 0.9108 - val_loss: 0.8039 - val_accuracy: 0.8125

# %%
# evaluation

# load testing set
test_metadata_filename = "test.csv"
df_test = pd.read_csv(test_metadata_filename)
n_testing_samples = len(df_test)
print("Number of testing samples:", n_testing_samples)
test_ds = tf.data.Dataset.from_tensor_slices((df_test["filepath"], df_test["label"]))

def prepare_for_testing(ds, cache=True, shuffle_buffer_size=1000):
  # This is a small dataset, only load it once, and keep it in memory.
  # use `.cache(filename)` to cache preprocessing work for datasets that don't
  # fit in memory.
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()

  ds = ds.shuffle(buffer_size=shuffle_buffer_size)

  return ds


test_ds = test_ds.map(process_path)
test_ds = prepare_for_testing(test_ds, cache="test-cached-data")
# Out:
# Number of testing samples: 600

# %%
# convert testing set to numpy array to fit in memory (don't do that when testing
# set is too large)
y_test = np.zeros((n_testing_samples,))
X_test = np.zeros((n_testing_samples, 299, 299, 3))
for i, (img, label) in enumerate(test_ds.take(n_testing_samples)):
  # print(img.shape, label.shape)
  X_test[i] = img
  y_test[i] = label.numpy()

print("y_test.shape:", y_test.shape)
# Out:
# y_test.shape: (600,)

# %%
# load the weights with the least loss
m.load_weights("benign-vs-malignant_64_rmsprop_0.399.h5")

# %%
print("Evaluating the model...")
loss, accuracy = m.evaluate(X_test, y_test, verbose=0)
print("Loss:", loss, "  Accuracy:", accuracy)
# Out:
# Evaluating the model...

# %%
from sklearn.metrics import accuracy_score

def get_predictions(threshold=None):
  """
  Returns predictions for binary classification given `threshold`
  For instance, if threshold is 0.3, then it'll output 1 (malignant) for that sample if
  the probability of 1 is 30% or more (instead of 50%)
  """
  y_pred = m.predict(X_test)
  if not threshold:
    threshold = 0.5
  result = np.zeros((n_testing_samples,))
  for i in range(n_testing_samples):
    # test melanoma probability
    if y_pred[i][0] >= threshold:
      result[i] = 1
    # else, it's 0 (benign)
  return result

threshold = 0.23
# get predictions with 23% threshold
# which means if the model is 23% sure or more that is malignant,
# it's assigned as malignant, otherwise it's benign
y_pred = get_predictions(threshold)
accuracy_after = accuracy_score(y_test, y_pred)
print("Accuracy after setting the threshold:", accuracy_after)
# Out:
# 19/19 [==============================] - 2s 123ms/step
# Accuracy after setting the threshold: 0.7883333333333333

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc, confusion_matrix

def plot_confusion_matrix(y_test, y_pred):
  cmn = confusion_matrix(y_test, y_pred)
  # Normalise
  cmn = cmn.astype('float') / cmn.sum(axis=1)[:, np.newaxis]
  # print it
  print(cmn)
  fig, ax = plt.subplots(figsize=(10,10))
  sns.heatmap(cmn, annot=True, fmt='.2f',
              xticklabels=[f"pred_{c}" for c in class_names],
              yticklabels=[f"true_{c}" for c in class_names],
              cmap="Blues"
              )
  plt.ylabel('Actual')
  plt.xlabel('Predicted')
  # plot the resulting confusion matrix
  plt.show()


def plot_roc_auc(y_true, y_pred):
    """
    This function plots the ROC curves and provides the scores.
    """
    # prepare for figure
    plt.figure()
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    # obtain ROC AUC
    roc_auc = auc(fpr, tpr)
    # print score
    print(f"ROC AUC: {roc_auc:.3f}")
    # plot ROC curve
    plt.plot(fpr, tpr, color="blue", lw=2,
                label='ROC curve (area = {f:.2f})'.format(d=1, f=roc_auc))
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curves')
    plt.legend(loc="lower right")
    plt.show()

plot_confusion_matrix(y_test, y_pred)
plot_roc_auc(y_test, y_pred)
sensitivity = sensitivity_score(y_test, y_pred)
specificity = specificity_score(y_test, y_pred)

print("Melanoma Sensitivity:", sensitivity)
print("Melanoma Specificity:", specificity)
# Out:
# [[0.5610766  0.4389234 ]
#  [0.23931624 0.76068376]]
# ROC AUC: 0.661
# Melanoma Sensitivity: 0.7606837606837606
# Melanoma Specificity: 0.5610766045548654

# %%
def plot_images(X_test, y_pred, y_test):
  predicted_class_names = np.array([class_names[int(round(id))] for id in y_pred])
  # some nice plotting
  plt.figure(figsize=(10,9))
  for n in range(30, 60):
      plt.subplot(6,5,n-30+1)
      plt.subplots_adjust(hspace = 0.3)
      plt.imshow(X_test[n])
      # get the predicted label
      predicted_label = predicted_class_names[n]
      # get the actual true label
      true_label = class_names[int(round(y_test[n]))]
      if predicted_label == true_label:
          color = "blue"
          title = predicted_label.title()
      else:
          color = "red"
          title = f"{predicted_label.title()}, true:{true_label.title()}"
      plt.title(title, color=color)
      plt.axis('off')
  _ = plt.suptitle("Model predictions (blue: correct, red: incorrect)")
  plt.show()

plot_images(X_test, y_pred, y_test)

# %%
# a function given a function, it predicts the class of the image
def predict_image_class(img_path, model, threshold=0.5):
  img = tf.keras.preprocessing.image.load_img(img_path, target_size=(299, 299))
  img = tf.keras.preprocessing.image.img_to_array(img)
  img = tf.expand_dims(img, 0) # Create a batch
  img = tf.keras.applications.inception_v3.preprocess_input(img)
  img = tf.image.convert_image_dtype(img, tf.float32)
  predictions = model.predict(img)
  score = predictions.squeeze()
  if score >= threshold:
    print(f"This image is {100 * score:.2f}% malignant.")
  else:
    print(f"This image is {100 * (1 - score):.2f}% benign.")

  plt.imshow(img[0])
  plt.axis('off')
  plt.show()

# %%
predict_image_class("data/test/melanoma/ISIC_0013767.jpg", m)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[0.6803772]]
# 0.6803772
# This image is 68.04% malignant.

# %%
predict_image_class("data/test/nevus/ISIC_0012092.jpg", m)
# Out:
# 1/1 [==============================] - 0s 50ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[0.21590327]]
# 0.21590327
# This image is 78.41% benign.

# %%
predict_image_class("data/test/seborrheic_keratosis/ISIC_0012136.jpg", m)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[0.13682997]]
# 0.13682997
# This image is 86.32% benign.
